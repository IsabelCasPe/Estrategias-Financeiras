# %%
# Reimportar bibliotecas após o reset
import numpy as np
import matplotlib.pyplot as plt

# %%
# Definir os parâmetros da calculadora
def calcular_juros_compostos(principal, taxa_juros, periodos):
    """
    Calcula o montante final com juros compostos.
    """
    montante = principal * (1 + taxa_juros) ** periodos
    return montante

# Configurações do exemplo
principal = 1000  # Investimento inicial (em unidades monetárias)
taxa_juros = 0.05  # Taxa de juros (5% ao período)
periodos = 10  # Número de períodos

# Calcular o montante final
montante_final = calcular_juros_compostos(principal, taxa_juros, periodos)

# Gerar dados para o gráfico
periodos_array = np.arange(1, periodos + 1)
montantes = [calcular_juros_compostos(principal, taxa_juros, t) for t in periodos_array]

# Criar o gráfico
plt.figure(figsize=(8, 5))
plt.plot(periodos_array, montantes, marker='o', label="Montante")
plt.title("Crescimento com Juros Compostos")
plt.xlabel("Períodos")
plt.ylabel("Montante (Unidades Monetárias)")
plt.grid(color='gray', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()

montante_final
# Out:
# 1628.894626777442

# %% [markdown]
# Calculadora de Juros Compostos.
#
# Montante Final:
# 1628.89
# 1628.89 unidades monetárias após 10 períodos com uma taxa de juros de 5% ao período, partindo de um principal de
# 1000
# 1000.
# O gráfico mostra como o montante cresce exponencialmente com o tempo.
